# %%
import pandas as pd
pd.set_option("display.max_columns",101)

# %%
df = pd.read_table('/home/bay001/projects/codebase/QC/data/new/QC.csv', sep=',', index_col=0)
df.reindex_axis(sorted(df.columns), axis=1)
# Out:
#                                            % of reads mapped to multiple loci  \
# PKM2-IP_R1_PKM2-IN_R2_M_S18_L001_R1_001.01                              0.00%
# PKM2-IP_R1_PMK2.merged                                                    NaN
# kbp550.11                                                               0.00%
#
#                                            % of reads mapped to too many loci  \
# PKM2-IP_R1_PKM2-IN_R2_M_S18_L001_R1_001.01                              7.69%
# PKM2-IP_R1_PMK2.merged                                                    NaN
# kbp550.11                                                               0.58%
#
#                                            % of reads unmapped: other  \
# PKM2-IP_R1_PKM2-IN_R2_M_S18_L001_R1_001.01                      0.25%
# PKM2-IP_R1_PMK2.merged                                            NaN
# kbp550.11                                                       0.49%
#
# ...
